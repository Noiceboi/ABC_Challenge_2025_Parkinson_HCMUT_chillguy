# %%
import pandas as pd
import numpy as np
import os

import shutil

# %%
os.chdir('/content/drive/MyDrive/ABC_challenge_2025/TrainingDataPD25')

# %%
acc = pd.read_csv('acc_sorted_by_time.csv')

# %%
test = pd.read_csv('TestActivities_UTC0.csv')

# %%
test['Started'] = pd.to_datetime(test['Started'])

# %%
test['Finished'] = pd.to_datetime(test['Finished'])
test['Updated'] = pd.to_datetime(test['Updated'])

# %%
test_time = test['Updated'].drop_duplicates().reset_index(drop=True)

# Display the first few values of the updated variable
test_time
# Out:
# 0    2024-09-08 22:47:00
# 1    2024-09-08 22:48:00
# 2    2024-09-08 22:49:00
# 3    2024-09-09 20:48:00
# 4    2024-09-10 20:15:00
#              ...
# 73   2024-09-12 19:34:00
# 74   2024-09-12 19:35:00
# 75   2024-09-12 19:36:00
# 76   2024-09-12 19:37:00
# 77   2024-09-12 19:38:00
# Name: Updated, Length: 78, dtype: datetime64[ns]

# %%
acc['Timestamp'] = pd.to_datetime(acc['Timestamp'])

# %%
acc
# Out:
#          MotionType               Timestamp      X       Y      Z
# 0              2804 2024-09-01 21:25:07.756  1.681   8.301  6.079
# 1              2804 2024-09-01 21:25:07.760  1.506   8.260  5.839
# 2              2804 2024-09-01 21:25:07.763  1.319   7.978  5.303
# 3              2804 2024-09-01 21:25:07.767  1.219   7.813  4.819
# 4              2804 2024-09-01 21:25:07.828  1.302   7.870  4.963
# ...             ...                     ...    ...     ...    ...
# 2041792        2816 2024-09-12 20:19:47.081  0.144 -10.098 -0.026
# 2041793        2816 2024-09-12 20:19:47.156  1.575  -9.971  1.024
# 2041794        2816 2024-09-12 20:19:47.251  0.543 -10.338 -0.275
# 2041795        2816 2024-09-12 20:19:47.349  1.647  -9.648  0.615
# 2041796        2816 2024-09-12 20:19:47.443  1.990  -9.804  0.464
#
# [2041797 rows x 5 columns]

# %%
acc['Timestamp_Just_Minute'] = acc['Timestamp'].apply(lambda x: x.replace(second=0))

# %%
acc['Timestamp_Just_Minute'] = acc['Timestamp_Just_Minute'].apply(lambda x: x.replace(microsecond=0))

# %%
acc
# Out:
#          MotionType               Timestamp      X       Y      Z  \
# 0              2804 2024-09-01 21:25:07.756  1.681   8.301  6.079
# 1              2804 2024-09-01 21:25:07.760  1.506   8.260  5.839
# 2              2804 2024-09-01 21:25:07.763  1.319   7.978  5.303
# 3              2804 2024-09-01 21:25:07.767  1.219   7.813  4.819
# 4              2804 2024-09-01 21:25:07.828  1.302   7.870  4.963
# ...             ...                     ...    ...     ...    ...
# 2041792        2816 2024-09-12 20:19:47.081  0.144 -10.098 -0.026
# 2041793        2816 2024-09-12 20:19:47.156  1.575  -9.971  1.024
# 2041794        2816 2024-09-12 20:19:47.251  0.543 -10.338 -0.275
# 2041795        2816 2024-09-12 20:19:47.349  1.647  -9.648  0.615
# 2041796        2816 2024-09-12 20:19:47.443  1.990  -9.804  0.464
#
#         Timestamp_Just_Minute
# 0         2024-09-01 21:25:00
# 1         2024-09-01 21:25:00
# 2         2024-09-01 21:25:00
# 3         2024-09-01 21:25:00
# 4         2024-09-01 21:25:00
# ...                       ...
# 2041792   2024-09-12 20:19:00
# 2041793   2024-09-12 20:19:00
# 2041794   2024-09-12 20:19:00
# 2041795   2024-09-12 20:19:00
# 2041796   2024-09-12 20:19:00
#
# [2041797 rows x 6 columns]

# %%
# Iterate over each 'Updated' time in test_time
for updated_time in test_time:
    # Filter rows in acc where 'Timestamp' matches the current 'Updated' time
    matched_rows = acc[acc['Timestamp_Just_Minute'] == updated_time]

    # If there are matching rows, save them to a new CSV file
    if not matched_rows.empty:
        file_name = f"NewFiles2/Acc_Test_{updated_time}.csv"
        matched_rows = matched_rows.drop('Timestamp_Just_Minute', axis = 1)
        matched_rows.to_csv(file_name, index=False)

# %%
pd.read_csv("NewFiles2/" + os.listdir('NewFiles2/')[0])
# Out:
#       MotionType                Timestamp      X      Y      Z
# 0           2815  2024-09-08 22:47:00.041  1.175  9.429  0.531
# 1           2815  2024-09-08 22:47:00.137  1.216  9.524  0.407
# 2           2815  2024-09-08 22:47:00.143  1.233  9.481  0.582
# 3           2815  2024-09-08 22:47:00.233  0.874  9.390  1.372
# 4           2815  2024-09-08 22:47:00.239  0.088  9.141  1.920
# ...          ...                      ...    ...    ...    ...
# 1038        2815  2024-09-08 22:47:59.715  2.033  5.897  8.198
# 1039        2815  2024-09-08 22:47:59.808  1.357  5.957  7.242
# 1040        2815  2024-09-08 22:47:59.812  1.159  5.639  7.999
# 1041        2815  2024-09-08 22:47:59.904  1.207  5.734  7.271
# 1042        2815  2024-09-08 22:47:59.999  0.948  5.368  8.025
#
# [1043 rows x 5 columns]

# %%
for i in os.listdir('NewFiles/'):
  file = pd.read_csv('NewFiles/' + i)

# %%
# Let's assume the dataframe is named 'df'
file['MotionType'].unique()  # This will display all unique values in the 'MotionType' column.
# Out:
# array([2815, 2803])

# %%
# Out:
#       MotionType                Timestamp       X      Y      Z
# 0           2816  2024-09-12 19:38:00.021  12.292 -5.329  5.832
# 1           2816  2024-09-12 19:38:00.027  11.143 -5.202  4.127
# 2           2816  2024-09-12 19:38:00.033   9.007 -5.472  0.359
# 3           2816  2024-09-12 19:38:00.040   7.357 -5.731 -4.185
# 4           2816  2024-09-12 19:38:00.046   5.227 -5.997 -8.250
# ...          ...                      ...     ...    ...    ...
# 3140        2816  2024-09-12 19:38:59.881  -0.624  4.999  5.985
# 3141        2816  2024-09-12 19:38:59.887  -0.440  4.465  5.973
# 3142        2816  2024-09-12 19:38:59.893   0.002  4.082  6.076
# 3143        2816  2024-09-12 19:38:59.990   0.426  4.073  6.311
# 3144        2816  2024-09-12 19:38:59.996   0.337  4.204  6.555
#
# [3145 rows x 5 columns]

# %%
len(os.listdir('Acc_Test/'))
# Out:
# 78

# %%
for i in os.listdir('Acc_Test/'):
  file = pd.read_csv('Acc_Test/' + i)
  print(file['MotionType'].value_counts())
# Out:
# MotionType
# 2815    812
# 2803    231
# Name: count, dtype: int64
# MotionType
# 2815    2152
# Name: count, dtype: int64
# MotionType
# 2815    3139
# Name: count, dtype: int64
# MotionType
# 2815    1395
# Name: count, dtype: int64
# MotionType
# 2812    3137
# Name: count, dtype: int64
# MotionType
# 2812    3142
# Name: count, dtype: int64
# MotionType
# 2812    3140
# Name: count, dtype: int64
# MotionType
# 2812    3140
# Name: count, dtype: int64
# MotionType
# 2812    3142
# Name: count, dtype: int64
# MotionType
# 2812    3138
# Name: count, dtype: int64
# MotionType
# 2812    3142
# Name: count, dtype: int64
# MotionType
# 2812    3138
# Name: count, dtype: int64
# MotionType
# 2812    3142
# Name: count, dtype: int64
# MotionType
# 2812    3141
# Name: count, dtype: int64
# MotionType
# 2812    3142
# Name: count, dtype: int64
# MotionType
# 2812    3138
# Name: count, dtype: int64
# MotionType
# 2812    3141
# Name: count, dtype: int64
# MotionType
# 2812    3140
# Name: count, dtype: int64
# MotionType
# 2813    3142
# Name: count, dtype: int64
# MotionType
# 2813    3140
# Name: count, dtype: int64
# MotionType
# 2813    3143
# Name: count, dtype: int64
# MotionType
# 2813    1977
# Name: count, dtype: int64
# MotionType
# 2813    1747
# Name: count, dtype: int64
# MotionType
# 2813    3141
# Name: count, dtype: int64
# MotionType
# 2813    3139
# Name: count, dtype: int64
# MotionType
# 2813    3141
# Name: count, dtype: int64
# MotionType
# 2813    3142
# Name: count, dtype: int64
# MotionType
# 2813    3142
# Name: count, dtype: int64
# MotionType
# 2813    3137
# Name: count, dtype: int64
# MotionType
# 2813    3143
# Name: count, dtype: int64
# MotionType
# 2813    3137
# Name: count, dtype: int64
# MotionType
# 2813    3142
# Name: count, dtype: int64
# MotionType
# 2813    3143
# Name: count, dtype: int64
# MotionType
# 2813    3142
# Name: count, dtype: int64
# MotionType
# 2813    3138
# Name: count, dtype: int64
# MotionType
# 2813    3141
# Name: count, dtype: int64
# MotionType
# 2813    3142
# Name: count, dtype: int64
# MotionType
# 2814    1287
# Name: count, dtype: int64
# MotionType
# 2814    1255
# Name: count, dtype: int64
# MotionType
# 2814    1195
# Name: count, dtype: int64
# MotionType
# 2814    1406
# Name: count, dtype: int64
# MotionType
# 2814    1537
# Name: count, dtype: int64
# MotionType
# 2814    3143
# Name: count, dtype: int64
# MotionType
# 2814    1180
# Name: count, dtype: int64
# MotionType
# 2814    1408
# Name: count, dtype: int64
# MotionType
# 2814    1410
# Name: count, dtype: int64
# MotionType
# 2814    1164
# Name: count, dtype: int64
# MotionType
# 2814    1286
# Name: count, dtype: int64
# MotionType
# 2814    1407
# Name: count, dtype: int64
# MotionType
# 2814    1384
# Name: count, dtype: int64
# MotionType
# 2814    1067
# Name: count, dtype: int64
# MotionType
# 2814    1167
# Name: count, dtype: int64
# MotionType
# 2815    2943
# Name: count, dtype: int64
# MotionType
# 2815    3141
# Name: count, dtype: int64
# MotionType
# 2815    3138
# Name: count, dtype: int64
# MotionType
# 2815    3138
# Name: count, dtype: int64
# MotionType
# 2815    3143
# Name: count, dtype: int64
# MotionType
# 2815    3143
# Name: count, dtype: int64
# MotionType
# 2815    3143
# Name: count, dtype: int64
# MotionType
# 2815    3144
# Name: count, dtype: int64
# MotionType
# 2815    3135
# Name: count, dtype: int64
# MotionType
# 2815    3145
# Name: count, dtype: int64
# MotionType
# 2815    3142
# Name: count, dtype: int64
# MotionType
# 2815    3137
# Name: count, dtype: int64
# MotionType
# 2815    3141
# Name: count, dtype: int64
# MotionType
# 2815    3140
# Name: count, dtype: int64
# MotionType
# 2815    3139
# Name: count, dtype: int64
# MotionType
# 2816    3138
# Name: count, dtype: int64
# MotionType
# 2816    3147
# Name: count, dtype: int64
# MotionType
# 2816    3138
# Name: count, dtype: int64
# MotionType
# 2816    3143
# Name: count, dtype: int64
# MotionType
# 2816    3138
# Name: count, dtype: int64
# MotionType
# 2816    3140
# Name: count, dtype: int64
# MotionType
# 2816    3137
# Name: count, dtype: int64
# MotionType
# 2816    3142
# Name: count, dtype: int64
# MotionType
# 2816    3142
# Name: count, dtype: int64
# MotionType
# 2816    3138
# Name: count, dtype: int64
# MotionType
# 2816    3145
# Name: count, dtype: int64

# %% [markdown]
# # TRAIN

# %%
train = pd.read_csv('TrainActivities.csv')

# %%
train
# Out:
#           ID  Activity Type ID  \
# 0    1130251              2806
# 1    1130254              2807
# 2    1130257              2807
# 3    1130261              2806
# 4    1130292              2806
# ..       ...               ...
# 337  1164181              2815
# 338  1164187              2806
# 339  1164217              2815
# 340  1164218              2815
# 341  1164219              2815
#
#                                          Activity Type          Started  \
# 0                      1 (FACING camera) Sit and stand  2024/09/02 6:16
# 1    2 (FACING camera) both hands SHAKING (sitting ...  2024/09/02 6:17
# 2    2 (FACING camera) both hands SHAKING (sitting ...  2024/09/02 6:18
# 3                      1 (FACING camera) Sit and stand  2024/09/02 6:20
# 4                      1 (FACING camera) Sit and stand  2024/09/02 6:42
# ..                                                 ...              ...
# 337  10 Slow walk (SHAKING hands/body, tiny step, h...              NaN
# 338                    1 (FACING camera) Sit and stand  2024/09/11 4:58
# 339  10 Slow walk (SHAKING hands/body, tiny step, h...  2024/09/11 5:09
# 340  10 Slow walk (SHAKING hands/body, tiny step, h...  2024/09/11 5:10
# 341  10 Slow walk (SHAKING hands/body, tiny step, h...  2024/09/11 5:11
#
#             Finished          Updated Subject
# 0    2024/09/02 6:16  2024/09/02 6:16     U22
# 1    2024/09/02 6:17  2024/09/02 6:17     U22
# 2    2024/09/02 6:18  2024/09/02 6:18     U22
# 3    2024/09/02 6:20  2024/09/02 6:20     U22
# 4    2024/09/02 6:42  2024/09/02 6:42      U2
# ..               ...              ...     ...
# 337              NaN  2024/09/11 4:55      U7
# 338  2024/09/11 4:58  2024/09/11 4:58      U7
# 339  2024/09/11 5:10  2024/09/11 5:10      U7
# 340  2024/09/11 5:10  2024/09/11 5:10      U7
# 341  2024/09/11 5:11  2024/09/11 5:11      U7
#
# [342 rows x 7 columns]

# %%
train['Started'] = pd.to_datetime(train['Started']) - pd.Timedelta(hours=9)
train['Finished'] = pd.to_datetime(train['Finished']) - pd.Timedelta(hours=9)
train['Updated'] = pd.to_datetime(train['Updated']) - pd.Timedelta(hours=9)

# %%
train
# Out:
#           ID  Activity Type ID  \
# 0    1130251              2806
# 1    1130254              2807
# 2    1130257              2807
# 3    1130261              2806
# 4    1130292              2806
# ..       ...               ...
# 337  1164181              2815
# 338  1164187              2806
# 339  1164217              2815
# 340  1164218              2815
# 341  1164219              2815
#
#                                          Activity Type             Started  \
# 0                      1 (FACING camera) Sit and stand 2024-09-01 21:16:00
# 1    2 (FACING camera) both hands SHAKING (sitting ... 2024-09-01 21:17:00
# 2    2 (FACING camera) both hands SHAKING (sitting ... 2024-09-01 21:18:00
# 3                      1 (FACING camera) Sit and stand 2024-09-01 21:20:00
# 4                      1 (FACING camera) Sit and stand 2024-09-01 21:42:00
# ..                                                 ...                 ...
# 337  10 Slow walk (SHAKING hands/body, tiny step, h...                 NaT
# 338                    1 (FACING camera) Sit and stand 2024-09-10 19:58:00
# 339  10 Slow walk (SHAKING hands/body, tiny step, h... 2024-09-10 20:09:00
# 340  10 Slow walk (SHAKING hands/body, tiny step, h... 2024-09-10 20:10:00
# 341  10 Slow walk (SHAKING hands/body, tiny step, h... 2024-09-10 20:11:00
#
#                Finished             Updated Subject
# 0   2024-09-01 21:16:00 2024-09-01 21:16:00     U22
# 1   2024-09-01 21:17:00 2024-09-01 21:17:00     U22
# 2   2024-09-01 21:18:00 2024-09-01 21:18:00     U22
# 3   2024-09-01 21:20:00 2024-09-01 21:20:00     U22
# 4   2024-09-01 21:42:00 2024-09-01 21:42:00      U2
# ..                  ...                 ...     ...
# 337                 NaT 2024-09-10 19:55:00      U7
# 338 2024-09-10 19:58:00 2024-09-10 19:58:00      U7
# 339 2024-09-10 20:10:00 2024-09-10 20:10:00      U7
# 340 2024-09-10 20:10:00 2024-09-10 20:10:00      U7
# 341 2024-09-10 20:11:00 2024-09-10 20:11:00      U7
#
# [342 rows x 7 columns]

# %%
train.to_csv('TrainActivities_UTC0.csv', index = False)

# %%
train = pd.read_csv('TrainActivities_UTC0.csv')

# %%
train
# Out:
#           ID  Activity Type ID  \
# 0    1130251              2806
# 1    1130254              2807
# 2    1130257              2807
# 3    1130261              2806
# 4    1130292              2806
# ..       ...               ...
# 337  1164181              2815
# 338  1164187              2806
# 339  1164217              2815
# 340  1164218              2815
# 341  1164219              2815
#
#                                          Activity Type              Started  \
# 0                      1 (FACING camera) Sit and stand  2024-09-01 21:16:00
# 1    2 (FACING camera) both hands SHAKING (sitting ...  2024-09-01 21:17:00
# 2    2 (FACING camera) both hands SHAKING (sitting ...  2024-09-01 21:18:00
# 3                      1 (FACING camera) Sit and stand  2024-09-01 21:20:00
# 4                      1 (FACING camera) Sit and stand  2024-09-01 21:42:00
# ..                                                 ...                  ...
# 337  10 Slow walk (SHAKING hands/body, tiny step, h...                  NaN
# 338                    1 (FACING camera) Sit and stand  2024-09-10 19:58:00
# 339  10 Slow walk (SHAKING hands/body, tiny step, h...  2024-09-10 20:09:00
# 340  10 Slow walk (SHAKING hands/body, tiny step, h...  2024-09-10 20:10:00
# 341  10 Slow walk (SHAKING hands/body, tiny step, h...  2024-09-10 20:11:00
#
#                 Finished              Updated Subject
# 0    2024-09-01 21:16:00  2024-09-01 21:16:00     U22
# 1    2024-09-01 21:17:00  2024-09-01 21:17:00     U22
# 2    2024-09-01 21:18:00  2024-09-01 21:18:00     U22
# 3    2024-09-01 21:20:00  2024-09-01 21:20:00     U22
# 4    2024-09-01 21:42:00  2024-09-01 21:42:00      U2
# ..                   ...                  ...     ...
# 337                  NaN  2024-09-10 19:55:00      U7
# 338  2024-09-10 19:58:00  2024-09-10 19:58:00      U7
# 339  2024-09-10 20:10:00  2024-09-10 20:10:00      U7
# 340  2024-09-10 20:10:00  2024-09-10 20:10:00      U7
# 341  2024-09-10 20:11:00  2024-09-10 20:11:00      U7
#
# [342 rows x 7 columns]

# %%
train_time = train['Updated'].drop_duplicates().reset_index(drop=True)

# Display the first few values of the updated variable
train_time
# Out:
# 0      2024-09-01 21:16:00
# 1      2024-09-01 21:17:00
# 2      2024-09-01 21:18:00
# 3      2024-09-01 21:20:00
# 4      2024-09-01 21:42:00
#               ...
# 128    2024-09-10 20:09:00
# 129    2024-09-10 19:55:00
# 130    2024-09-10 19:58:00
# 131    2024-09-10 20:10:00
# 132    2024-09-10 20:11:00
# Name: Updated, Length: 133, dtype: object

# %%
# Iterate over each 'Updated' time in train_time
for updated_time in train_time:
    # Filter rows in acc where 'Timestamp' matches the current 'Updated' time
    matched_rows = acc[acc['Timestamp_Just_Minute'] == updated_time]

    # If there are matching rows, save them to a new CSV file
    if not matched_rows.empty:
        file_name = f"Acc_Train/Acc_Train_{updated_time}.csv"
        matched_rows = matched_rows.drop('Timestamp_Just_Minute', axis = 1)
        matched_rows.to_csv(file_name, index=False)

# %%
pd.read_csv("Acc_Train/" + os.listdir('Acc_Train/')[3])
# Out:
#      MotionType                Timestamp      X      Y       Z
# 0          2804  2024-09-03 10:57:00.034  0.359  4.458   7.583
# 1          2804  2024-09-03 10:57:00.169  0.651  5.158   5.475
# 2          2804  2024-09-03 10:57:00.303  0.257  4.430   9.669
# 3          2804  2024-09-03 10:57:00.436 -0.029  3.555  13.697
# 4          2804  2024-09-03 10:57:00.571  0.469  5.077   5.588
# ..          ...                      ...    ...    ...     ...
# 717        2804  2024-09-03 10:57:59.405 -0.297  3.370   9.167
# 718        2804  2024-09-03 10:57:59.538 -0.470  3.284   9.039
# 719        2804  2024-09-03 10:57:59.671 -0.820  3.170   9.191
# 720        2804  2024-09-03 10:57:59.808 -0.724  3.142   9.293
# 721        2804  2024-09-03 10:57:59.934 -0.802  3.041   9.325
#
# [722 rows x 5 columns]

# %%
train
# Out:
#           ID  Activity Type ID  \
# 0    1130251              2806
# 1    1130254              2807
# 2    1130257              2807
# 3    1130261              2806
# 4    1130292              2806
# ..       ...               ...
# 337  1164181              2815
# 338  1164187              2806
# 339  1164217              2815
# 340  1164218              2815
# 341  1164219              2815
#
#                                          Activity Type              Started  \
# 0                      1 (FACING camera) Sit and stand  2024-09-01 21:16:00
# 1    2 (FACING camera) both hands SHAKING (sitting ...  2024-09-01 21:17:00
# 2    2 (FACING camera) both hands SHAKING (sitting ...  2024-09-01 21:18:00
# 3                      1 (FACING camera) Sit and stand  2024-09-01 21:20:00
# 4                      1 (FACING camera) Sit and stand  2024-09-01 21:42:00
# ..                                                 ...                  ...
# 337  10 Slow walk (SHAKING hands/body, tiny step, h...                  NaN
# 338                    1 (FACING camera) Sit and stand  2024-09-10 19:58:00
# 339  10 Slow walk (SHAKING hands/body, tiny step, h...  2024-09-10 20:09:00
# 340  10 Slow walk (SHAKING hands/body, tiny step, h...  2024-09-10 20:10:00
# 341  10 Slow walk (SHAKING hands/body, tiny step, h...  2024-09-10 20:11:00
#
#                 Finished              Updated Subject
# 0    2024-09-01 21:16:00  2024-09-01 21:16:00     U22
# 1    2024-09-01 21:17:00  2024-09-01 21:17:00     U22
# 2    2024-09-01 21:18:00  2024-09-01 21:18:00     U22
# 3    2024-09-01 21:20:00  2024-09-01 21:20:00     U22
# 4    2024-09-01 21:42:00  2024-09-01 21:42:00      U2
# ..                   ...                  ...     ...
# 337                  NaN  2024-09-10 19:55:00      U7
# 338  2024-09-10 19:58:00  2024-09-10 19:58:00      U7
# 339  2024-09-10 20:10:00  2024-09-10 20:10:00      U7
# 340  2024-09-10 20:10:00  2024-09-10 20:10:00      U7
# 341  2024-09-10 20:11:00  2024-09-10 20:11:00      U7
#
# [342 rows x 7 columns]

# %%
len(os.listdir('Acc_Train/'))
# Out:
# 129

# %%
train
# Out:
#           ID  Activity Type ID  \
# 0    1130251              2806
# 1    1130254              2807
# 2    1130257              2807
# 3    1130261              2806
# 4    1130292              2806
# ..       ...               ...
# 337  1164181              2815
# 338  1164187              2806
# 339  1164217              2815
# 340  1164218              2815
# 341  1164219              2815
#
#                                          Activity Type              Started  \
# 0                      1 (FACING camera) Sit and stand  2024-09-01 21:16:00
# 1    2 (FACING camera) both hands SHAKING (sitting ...  2024-09-01 21:17:00
# 2    2 (FACING camera) both hands SHAKING (sitting ...  2024-09-01 21:18:00
# 3                      1 (FACING camera) Sit and stand  2024-09-01 21:20:00
# 4                      1 (FACING camera) Sit and stand  2024-09-01 21:42:00
# ..                                                 ...                  ...
# 337  10 Slow walk (SHAKING hands/body, tiny step, h...                  NaN
# 338                    1 (FACING camera) Sit and stand  2024-09-10 19:58:00
# 339  10 Slow walk (SHAKING hands/body, tiny step, h...  2024-09-10 20:09:00
# 340  10 Slow walk (SHAKING hands/body, tiny step, h...  2024-09-10 20:10:00
# 341  10 Slow walk (SHAKING hands/body, tiny step, h...  2024-09-10 20:11:00
#
#                 Finished              Updated Subject
# 0    2024-09-01 21:16:00  2024-09-01 21:16:00     U22
# 1    2024-09-01 21:17:00  2024-09-01 21:17:00     U22
# 2    2024-09-01 21:18:00  2024-09-01 21:18:00     U22
# 3    2024-09-01 21:20:00  2024-09-01 21:20:00     U22
# 4    2024-09-01 21:42:00  2024-09-01 21:42:00      U2
# ..                   ...                  ...     ...
# 337                  NaN  2024-09-10 19:55:00      U7
# 338  2024-09-10 19:58:00  2024-09-10 19:58:00      U7
# 339  2024-09-10 20:10:00  2024-09-10 20:10:00      U7
# 340  2024-09-10 20:10:00  2024-09-10 20:10:00      U7
# 341  2024-09-10 20:11:00  2024-09-10 20:11:00      U7
#
# [342 rows x 7 columns]

# %%
for i in os.listdir('Acc_Train/'):
  file = pd.read_csv('Acc_Train/' + i)
  print(file['MotionType'].value_counts())
